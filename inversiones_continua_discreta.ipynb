# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from matplotlib.pylab import hist, show
def congruencial(a,b,m,x0,n):
    xn=0.0
    un=0.0
    list = []
    for i in range(0,n):
        xn=(a*x0 + b)%m
        un=xn/float(m)
        #print un
        list.insert(i,un)
        x0=xn
    return list
def inversionDiscreta(n,met):
    metodo=congruencial(89.0,56.0,2147483647.0,24.0,n)
    funacu=[]
    x=[]
    px=[]
    temp=0.0
    funacu.append(0)
    if met==1:
        lamda=input('Valor de Lambda: ')
        for j in range(20):
            x.append(j)
            px.append(poisson(lamda,j)[j])
    else:
        if met==2:
            p=input('Valor de p: ')
            for j in range(2):
                x.append(j)
                px.append(bernoulli(p,2)[j])
        else:
            if met==3:
                p=input('Valor de p: ')
                for j in range(20):
                    x.append(j)
                    px.append(binomial(p,j)[j]) 
            else:
                print '---------------ERROR---------------'
    for i in range(len(px)):
        temp+=px[i]
        funacu.append(temp)
    print 'Resultado por inversión: '
    histo=[]
    for i in range(len(metodo)):
        for j in range(len(funacu)-1):
            if(metodo[i]>funacu[j] and metodo[i]<=funacu[j+1]):
                histo.append(x[j])
    plt.hist(histo)
    plt.show()
    print "Variable aleatoria x con valor:"
    print x
    print "Valor de p(x)"
    print px
    print "F.D.A P(X)"
    print funacu
    print "Valores aleatorios generador por el método congruencial"
    print metodo
    
def inversionContinua(n,met):
    metodo=congruencial(89.0,56.0,2147483647.0,24.0,n)
    if met==1:
        lamda=input('Valor de lamda: ')
        exponencial(lamda,metodo)
    else:
        if met==2:
            sigma=input('Valor de sigma: ')
            Rayleigh(sigma,metodo)
        else:
            if met==3:
                miu=input('Valor de miu: ')
                b=input('Valor de b: ')
                laplace(miu,b,metodo)
            else:
                print('---------------ERROR---------------')  
def poisson(lamda,k):
    arregloPos=[]
    for i in range(1000):
        val=(math.exp(-1*lamda)*(lamda**k)/math.factorial(k))+0.0
        arregloPos.append(val)
    return arregloPos
def bernoulli(p,muestras):
    arregloPos=[]
    for i in range(muestras):
        val=(p**i)*((1-p)**(1-i))
        arregloPos.append(val)
    return arregloPos
def binomial(p,k):
    arregloPos=[]
    for i in range(1000):
        comb=math.factorial(20)/math.factorial(k)*math.factorial(20-k)
        val=comb*math.pow(p,k)*math.pow(1-p,20-k)
        arregloPos.append(val)
    return arregloPos
def exponencial(lamda,lista):
    mat=[]
    for i in range(len(lista)):
        inv=-1*math.log(1-lista[i])/lamda
        mat.append(inv)
        print 'p: ',lista[i]
        print 'Q(p): ',inv
        print '__________'
    ##plt.plot(lista,mat)
    plt.hist(mat)
    plt.show()
def Rayleigh(sigma,lista):
    mat=[]
    for i in range(len(lista)):
        inv=sigma*math.pow(-1*math.log(math.pow(1-lista[i],2)),0.5)
        mat.append(inv)
        print 'p: ',lista[i]
        print 'Q(p): ',inv
        print '________'
    plt.hist(mat)
    #plt.plot(lista,mat)
    plt.show()
def laplace(miu,b,lista):
    val=1
    mat=[]
    for i in range(len(lista)):
        sgn=lista[i]-0.5
        if sgn>0:
            val=1
        else:
            if sgn==0:
                val=0
            else:
                if sgn<0:
                    val=-1
        inv=miu-b*val*math.log(1-2*abs(lista[i]-0.5))
        mat.append(inv)
        print 'p: ',lista[i]
        print 'Q(p): ',inv
        print '________'
    plt.hist(mat)
    #plt.plot(lista,mat)
    plt.show()    
print('1) Para Generador de variables aleatorias contínuas por Inversión Contínua')
print('2. Para Generador de variables aleatorias discretas por Inversión Discreta')
tipoInv=input('Que tipo de generador de V.A desea?')
if tipoInv==1:
    print('1. Exponencial')
    print('2. Rayleigh')
    print('3. Laplace')
    metodo=input('Elija la distribucion: ')
    num=input('Cantidad a generar de números aleatorios: ')
    inversionContinua(num,metodo)
else:
    if tipoInv==2:
        print('1. Poisson')
        print('2. Bernoulli')
        print('3. Binomial')
        metodoDis=input('Elija la distribucion: ')
        numDi=input('Cantidad a generar de números aleatorios: ')
        inversionDiscreta(numDi,metodoDis)
    else:
        print('---------------ERROR---------------')
# Out:
# 1) Para Generador de variables aleatorias contínuas por Inversión Contínua
# 2. Para Generador de variables aleatorias discretas por Inversión Discreta
# Que tipo de generador de V.A desea?1
# 1. Exponencial
# 2. Rayleigh
# 3. Laplace
# Elija la distribucion: 1
# Cantidad a generar de nÃºmeros aleatorios: 10
# Valor de lamda: 6
# p:  1.02072954225e-06
# Q(p):  1.70121677195e-07
# __________
# p:  9.08710062927e-05
# Q(p):  1.51458558855e-05
# __________
# p:  0.00808754563708
# Q(p):  0.00135340454033
# __________
# p:  0.719791587777
# Q(p):  0.21203693722
# __________
# p:  0.0614513382602
# Q(p):  0.0105700956252
# __________
# p:  0.469169131233
# Q(p):  0.105551970507
# __________
# p:  0.756052705811
# Q(p):  0.235133847408
# __________
# p:  0.288690843288
# Q(p):  0.0567746873532
# __________
# p:  0.693485078725
# Q(p):  0.197081473667
# __________
# p:  0.720172032584
# Q(p):  0.212263377787
# __________
