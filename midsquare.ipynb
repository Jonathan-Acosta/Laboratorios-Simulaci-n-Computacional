# %% [markdown]
# # MIDSQUARE

# %% [markdown]
# ## Este método de generador de números aleatorios

# %%
import sys
while True:
        opcion = input("\menú principal: \n1. de generador números aleatorios. \n2. salir.\n")
        if opcion == 1:
                print '\n**midsquare*'
                x0 = input("\nIngrese la semilla:  ")
                longitud_x0 = len(str(x0))

                if longitud_x0 %2 == 0:
                        cantidad = input("Ingrese cuantos números aleatorios desea generar: ")
                        print "\n"
                        for i in range(0,cantidad):
                                numCuadrado = str(x0*x0)
                                if len(numCuadrado)< 2*longitud_x0:
                                        cantidadDeCerosPorAgregar = 2*longitud_x0 - len(numCuadrado)
                                        cadenaDeCeros = "" 
                                        for ii in range(0,cantidadDeCerosPorAgregar):
                                                cadenaDeCeros = '0' + cadenaDeCeros
                                        numCuadrado = cadenaDeCeros + numCuadrado
                                #print "Numero cuadrado" + str(i) + " = " + numCuadrado
                                xi = numCuadrado[ int (0.5*longitud_x0) : int (0.5*longitud_x0 + longitud_x0) ]
                                #print "X" + str(i) + " = " + xi
                                ui = '0.'+ xi
                                print "U" + str(i) + " = " + ui
                                x0 = int(xi)

                else: 
                        print 'Error: El valor de la semilla debe ser un número de cifras par. \n'

        elif opcion == 2:
                sys.exit()

        else:
                print 'Elija una opción válida.\n'
# Out:
# \menÃº principal:
# 1. de generador nÃºmeros aleatorios.
# 2. salir.
# 1
#
# **midsquare*
#
# Ingrese la semilla:  40
# Ingrese cuantos nÃºmeros aleatorios desea generar: 100
#
#
# U0 = 0.60
# U1 = 0.60
# U2 = 0.60
# U3 = 0.60
# U4 = 0.60
# U5 = 0.60
# U6 = 0.60
# U7 = 0.60
# U8 = 0.60
# U9 = 0.60
# U10 = 0.60
# U11 = 0.60
# U12 = 0.60
# U13 = 0.60
# U14 = 0.60
# U15 = 0.60
# U16 = 0.60
# U17 = 0.60
# U18 = 0.60
# U19 = 0.60
# U20 = 0.60
# U21 = 0.60
# U22 = 0.60
# U23 = 0.60
# U24 = 0.60
# U25 = 0.60
# U26 = 0.60
# U27 = 0.60
# U28 = 0.60
# U29 = 0.60
# U30 = 0.60
# U31 = 0.60
# U32 = 0.60
# U33 = 0.60
# U34 = 0.60
# U35 = 0.60
# U36 = 0.60
# U37 = 0.60
# U38 = 0.60
# U39 = 0.60
# U40 = 0.60
# U41 = 0.60
# U42 = 0.60
# U43 = 0.60
# U44 = 0.60
# U45 = 0.60
# U46 = 0.60
# U47 = 0.60
# U48 = 0.60
# U49 = 0.60
# U50 = 0.60
# U51 = 0.60
# U52 = 0.60
# U53 = 0.60
# U54 = 0.60
# U55 = 0.60
# U56 = 0.60
# U57 = 0.60
# U58 = 0.60
# U59 = 0.60
# U60 = 0.60
# U61 = 0.60
# U62 = 0.60
# U63 = 0.60
# U64 = 0.60
# U65 = 0.60
# U66 = 0.60
# U67 = 0.60
# U68 = 0.60
# U69 = 0.60
# U70 = 0.60
# U71 = 0.60
# U72 = 0.60
# U73 = 0.60
# U74 = 0.60
# U75 = 0.60
# U76 = 0.60
# U77 = 0.60
# U78 = 0.60
# U79 = 0.60
# U80 = 0.60
# U81 = 0.60
# U82 = 0.60
# U83 = 0.60
# U84 = 0.60
# U85 = 0.60
# U86 = 0.60
# U87 = 0.60
# U88 = 0.60
# U89 = 0.60
# U90 = 0.60
# U91 = 0.60
# U92 = 0.60
# U93 = 0.60
# U94 = 0.60
# U95 = 0.60
# U96 = 0.60
# U97 = 0.60
# U98 = 0.60
# U99 = 0.60
